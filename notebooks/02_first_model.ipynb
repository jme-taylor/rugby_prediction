# %%
import numpy as np
import pandas as pd 

from rugby_prediction.constants import DATA_FOLDER

# %%
# reading in raw data
raw_match_data_path = DATA_FOLDER.joinpath('match_data.csv')
raw_match_data = pd.read_csv(raw_match_data_path)
raw_match_data.head()
# Out:
#    match_id                       unique_id         match_date  \
# 0     24843    s:300~l:8323~e:24843~c:24843  2005-02-05T14:00Z
# 1     24844    s:300~l:8323~e:24844~c:24844  2005-02-05T17:30Z
# 2    128030  s:300~l:8007~e:128030~c:128030  2005-02-05T14:00Z
# 3    128028  s:300~l:8007~e:128028~c:128028  2005-02-05T15:00Z
# 4    128029  s:300~l:8007~e:128029~c:128029  2005-02-05T19:45Z
#
#                                  venue         city    state  neutral_site  \
# 0                      Stade de France  Saint-Denis  Reunion         False
# 1                 Principality Stadium      Cardiff    Wales         False
# 2                     Twickenham Stoop       London  England         False
# 3  cinch Stadium at Franklin's Gardens  Northampton  England         False
# 4                    Recreation Ground         Bath  England         False
#
#   indoor  team_1_id         team_1_name  ... team_1_score team_1_winner  \
# 0  False          9              France  ...           16          True
# 1  False          4               Wales  ...           11          True
# 2  False      25901          Harlequins  ...           38          True
# 3  False      25907  Northampton Saints  ...           20         False
# 4  False      25898          Bath Rugby  ...            6         False
#
#    team_2_id       team_2_name  team_2_abbreviation team_2_home_away  \
# 0          2          Scotland                 SCOT             away
# 1          1           England                  ENG             away
# 2      25900  Gloucester Rugby                GLOUC             away
# 3      25909          Saracens                SARAC             away
# 4      25903  Leicester Tigers                LEICS             away
#
#   team_2_score team_2_winner            competition season
# 0            9         False            Six Nations   2005
# 1            9         False            Six Nations   2005
# 2            9         False  Gallagher Premiership   2005
# 3           21          True  Gallagher Premiership   2005
# 4            6         False  Gallagher Premiership   2005
#
# [5 rows x 22 columns]

# %%
# create conceded columns
raw_match_data['team_1_conceded'] = raw_match_data['team_2_score']
raw_match_data['team_2_conceded'] = raw_match_data['team_1_score']

# %%
# create previous score + previous conceded columns
raw_match_data['team_1_prev_score'] = raw_match_data.sort_values(by='match_date').groupby('team_1_id')['team_1_score'].shift(1)
raw_match_data['team_1_prev_conceded'] = raw_match_data.sort_values(by='match_date').groupby('team_1_id')['team_1_conceded'].shift(1)
raw_match_data['team_2_prev_score'] = raw_match_data.sort_values(by='match_date').groupby('team_2_id')['team_2_score'].shift(1)
raw_match_data['team_2_prev_conceded'] = raw_match_data.sort_values(by='match_date').groupby('team_2_id')['team_2_conceded'].shift(1)

# %%
# create rolling average columns of conceded levels
raw_match_data['team_1_rolling_score'] = raw_match_data.sort_values(by='match_date').groupby('team_1_id')['team_1_prev_score'].rolling(5).mean().reset_index(level='team_1_id', drop=True)
raw_match_data['team_1_rolling_conceded'] = raw_match_data.sort_values(by='match_date').groupby('team_1_id')['team_1_prev_conceded'].rolling(5).mean().reset_index(level='team_1_id', drop=True)
raw_match_data['team_2_rolling_score'] = raw_match_data.sort_values(by='match_date').groupby('team_2_id')['team_2_prev_score'].rolling(5).mean().reset_index(level='team_2_id', drop=True)
raw_match_data['team_2_rolling_conceded'] = raw_match_data.sort_values(by='match_date').groupby('team_2_id')['team_2_prev_conceded'].rolling(5).mean().reset_index(level='team_2_id', drop=True)

# %%
# imputing missing values - with median score
all_scores = raw_match_data['team_1_score'].tolist() + raw_match_data['team_2_score'].tolist()
median_score = np.median(all_scores)
median_score
# Out:
# 21.0

# %%
from rugby_prediction.preprocess import drop_competitions

raw_match_data = drop_competitions(raw_match_data)

# %%
# create row per team, per match
from rugby_prediction.preprocess import TEAM_COLUMNS, CORE_COLUMNS, transform_raw_data_to_team_level

team_columns_with_conceded = TEAM_COLUMNS + ['conceded', 'rolling_score', 'rolling_conceded']
team_level_data = transform_raw_data_to_team_level(raw_match_data, team_columns_with_conceded)
team_level_data.head()
# Out:
#    match_id                       unique_id         match_date  \
# 0     24843    s:300~l:8323~e:24843~c:24843  2005-02-05T14:00Z
# 1     24843    s:300~l:8323~e:24843~c:24843  2005-02-05T14:00Z
# 2     24844    s:300~l:8323~e:24844~c:24844  2005-02-05T17:30Z
# 3     24844    s:300~l:8323~e:24844~c:24844  2005-02-05T17:30Z
# 4    128030  s:300~l:8007~e:128030~c:128030  2005-02-05T14:00Z
#
#                   venue         city    state  neutral_site indoor  \
# 0       Stade de France  Saint-Denis  Reunion         False  False
# 1       Stade de France  Saint-Denis  Reunion         False  False
# 2  Principality Stadium      Cardiff    Wales         False  False
# 3  Principality Stadium      Cardiff    Wales         False  False
# 4      Twickenham Stoop       London  England         False  False
#
#              competition  season  ...  conceded rolling_score  \
# 0            Six Nations    2005  ...         9           NaN
# 1            Six Nations    2005  ...        16           NaN
# 2            Six Nations    2005  ...         9           NaN
# 3            Six Nations    2005  ...        11           NaN
# 4  Gallagher Premiership    2005  ...         9           NaN
#
#    rolling_conceded id_opposition  home_away_opposition  score_opposition  \
# 0               NaN             2                  away                 9
# 1               NaN             9                  home                16
# 2               NaN             1                  away                 9
# 3               NaN             4                  home                11
# 4               NaN         25900                  away                 9
#
#    winner_opposition  conceded_opposition rolling_score_opposition  \
# 0              False                   16                      NaN
# 1               True                    9                      NaN
# 2              False                   11                      NaN
# 3               True                    9                      NaN
# 4              False                   38                      NaN
#
#    rolling_conceded_opposition
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 24 columns]

# %%
from rugby_prediction.preprocess import map_competitions

team_level_data = map_competitions(team_level_data)
team_level_data['home'] = np.where(team_level_data['home_away'] == 'home', True, False)
team_level_data.head()
# Out:
#    match_id                       unique_id         match_date  \
# 0     24843    s:300~l:8323~e:24843~c:24843  2005-02-05T14:00Z
# 1     24843    s:300~l:8323~e:24843~c:24843  2005-02-05T14:00Z
# 2     24844    s:300~l:8323~e:24844~c:24844  2005-02-05T17:30Z
# 3     24844    s:300~l:8323~e:24844~c:24844  2005-02-05T17:30Z
# 4    128030  s:300~l:8007~e:128030~c:128030  2005-02-05T14:00Z
#
#                   venue         city    state  neutral_site indoor  season  \
# 0       Stade de France  Saint-Denis  Reunion         False  False    2005
# 1       Stade de France  Saint-Denis  Reunion         False  False    2005
# 2  Principality Stadium      Cardiff    Wales         False  False    2005
# 3  Principality Stadium      Cardiff    Wales         False  False    2005
# 4      Twickenham Stoop       London  England         False  False    2005
#
#       id  ... home_away_opposition  score_opposition winner_opposition  \
# 0      9  ...                 away                 9             False
# 1      2  ...                 home                16              True
# 2      4  ...                 away                 9             False
# 3      1  ...                 home                11              True
# 4  25901  ...                 away                 9             False
#
#    conceded_opposition  rolling_score_opposition  rolling_conceded_opposition  \
# 0                   16                       NaN                          NaN
# 1                    9                       NaN                          NaN
# 2                   11                       NaN                          NaN
# 3                    9                       NaN                          NaN
# 4                   38                       NaN                          NaN
#
#    international_competition club_competition  unknown_competition   home
# 0                          1                0                    0   True
# 1                          1                0                    0  False
# 2                          1                0                    0   True
# 3                          1                0                    0  False
# 4                          0                1                    0   True
#
# [5 rows x 27 columns]

# %%
training_columns = [
    'neutral_site',
    'season',
    'home',
    'rolling_score',
    'rolling_conceded_opposition',
    'international_competition',
    'club_competition',
    'unknown_competition',
]
target_column = ['score']

# %%
X = team_level_data[training_columns]
y = team_level_data[target_column]
X.head()
# Out:
#    neutral_site  season   home  rolling_score  rolling_conceded_opposition  \
# 0         False    2005   True            NaN                          NaN
# 1         False    2005  False            NaN                          NaN
# 2         False    2005   True            NaN                          NaN
# 3         False    2005  False            NaN                          NaN
# 4         False    2005   True            NaN                          NaN
#
#    international_competition  club_competition  unknown_competition
# 0                          1                 0                    0
# 1                          1                 0                    0
# 2                          1                 0                    0
# 3                          1                 0                    0
# 4                          0                 1                    0

# %%
X = X.fillna(median_score)
X.head()
# Out:
#    neutral_site  season   home  rolling_score  rolling_conceded_opposition  \
# 0         False    2005   True           21.0                         21.0
# 1         False    2005  False           21.0                         21.0
# 2         False    2005   True           21.0                         21.0
# 3         False    2005  False           21.0                         21.0
# 4         False    2005   True           21.0                         21.0
#
#    international_competition  club_competition  unknown_competition
# 0                          1                 0                    0
# 1                          1                 0                    0
# 2                          1                 0                    0
# 3                          1                 0                    0
# 4                          0                 1                    0

# %%
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score

xgbr = XGBRegressor()
scores = cross_val_score(xgbr, X_train, y_train, cv=10, scoring='neg_mean_absolute_error')
np.mean(-scores)
# Out:
# 9.524835762254124

# %% [markdown]
# This model doesn't beat our MAE score of 9.34 using the linear regression model that we built in our first notebook. Due to this, we're going to experiment with some other windows for the rolling function - to see if that helps us get a better score.
